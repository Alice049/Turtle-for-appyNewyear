# %%
from turtle import *

pensize(5)
pencolor('green')
circle(100,90)

pu()
goto(0,0)
seth(0)
pd()
pencolor('orange')
circle(100,-90)

pu()
goto(0,0)
seth(0)
pd()
pencolor('blue')
circle(-100,90)

pu()
goto(0,0)
seth(0)
pd()
pencolor('red')
circle(-100,-90)

# %%
from turtle import*

speed(10)

color('pink')
pensize(5)
circle(radius=100)

pencolor('black')

pu()
goto(-45,92)
pd()
begin_fill()
color((0,0,0),(0,0,0.1))
circle(radius=15)

pu()
goto(45,92)
pd()
circle(radius=15)
end_fill()

pu()
goto(20,60)
color('pink')
pd()
begin_fill()
goto(-20,60)
goto(0,45)
goto(20,60)
end_fill()

goto(0,45)
goto(20,60)
end_fill()

goto(0,45)
goto(0,40)
seth(-90)
circle(10,120)
pu()
goto(0,40)
seth(-90)
pd()
circle(-10,120)

pu()
goto(-60,180)
seth(200)
pd()
circle(radius=350,extent=90)
goto(-98,110)
pu()
goto(60,180)
seth(-20)
pd()
circle(radius=-350,extent=90)
goto(98,110)



#body
pu()
goto(20,3)
seth(-25)
pd()
circle(radius=-250,extent=25)
circle(radius=-135,extent=260)
seth(50)
circle(radius=-250,extent=25)

#hand
pu()
seth(180)
goto(-30,-3)
pd()
circle(radius=248,extent=30)
circle(radius=29,extent=185)


pu()
seth(0)
goto(30,-3)
pd()
circle(radius=-248,extent=30)
circle(radius=-27,extent=184)

#leg
pu()
goto(-162,-260)
pd()
seth(0)
circle(radius=41)
pu()
goto(164,-260)
pd()
circle(radius=41)

import turtle

IWanttoSay=turtle.textinput("IWanttoSay","BEST WISH")
print(IWanttoSay)

done
# Out:
#   File "<ipython-input-5-bc787ac5727d>", line 100
#     import turtle *
#                   ^
# SyntaxError: invalid syntax
